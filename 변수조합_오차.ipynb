# %%
import pandas as pd

# Load the data from the uploaded file
results_df = pd.read_csv('results.csv')

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the scaler
scaler = MinMaxScaler()

# Invert the metrics that should be minimized (so that higher is always better)
results_df["inv_mae"] = 1 / results_df["mae"]
results_df["inv_mse"] = 1 / results_df["mse"]
results_df["inv_rmse"] = 1 / results_df["rmse"]

# Normalize the metrics to the range [0, 1]
results_df["norm_mae"] = scaler.fit_transform(results_df[["inv_mae"]])
results_df["norm_mse"] = scaler.fit_transform(results_df[["inv_mse"]])
results_df["norm_rmse"] = scaler.fit_transform(results_df[["inv_rmse"]])
results_df["norm_r2"] = scaler.fit_transform(results_df[["r2"]])

# Compute the aggregate score as the sum of the normalized metrics
results_df["aggregate_score"] = results_df["norm_mae"] + results_df["norm_mse"] + results_df["norm_rmse"] + results_df["norm_r2"]

# Sort by the aggregate score in descending order and select the top 10 combinations
top_10_combinations = results_df.sort_values(by="aggregate_score", ascending=False).head(10)

top_10_combinations[["features", "mae", "mse", "rmse", "r2", "aggregate_score"]]
# Out:
#                                                features            mae
# 3080  ['Humidity', 'Vapor_pressure(hPa)', 'sunshine(...  485728.264604  \
# 3410  ['Prec(mm)', 'Humidity', 'Vapor_pressure(hPa)'...  485945.892376
# 3835  ['Prec(mm)', 'Humidity', 'Vapor_pressure(hPa)'...  486197.212167
# 3876  ['Prec(mm)', 'Humidity', 'Vapor_pressure(hPa)'...  482336.141317
# 3670  ['Humidity', 'Vapor_pressure(hPa)', 'Dew_Point...  486658.589110
# 3466  ['Prec(mm)', 'Humidity', 'Dew_Point(C)', 'suns...  486327.369221
# 2870  ['Prec(mm)', 'Vapor_pressure(hPa)', 'sunshine(...  486740.273112
# 2408  ['Vapor_pressure(hPa)', 'sunshine(hr)', 'Snowf...  486786.788833
# 3136  ['Humidity', 'Dew_Point(C)', 'sunshine(hr)', '...  486697.676101
# 3691  ['Humidity', 'Vapor_pressure(hPa)', 'Local Atm...  486149.746144
#
#                mse           rmse        r2  aggregate_score
# 3080  5.959573e+11  771982.737605  0.946168         3.980330
# 3410  5.961588e+11  772113.224179  0.946149         3.977576
# 3835  5.969243e+11  772608.746699  0.946080         3.970434
# 3876  6.000505e+11  774629.244646  0.945798         3.969640
# 3670  5.968559e+11  772564.503220  0.946087         3.968293
# 3466  5.977611e+11  773150.124393  0.946005         3.963469
# 2870  5.976485e+11  773077.282025  0.946015         3.961935
# 2408  5.979309e+11  773259.914619  0.945989         3.959573
# 3136  5.981137e+11  773378.084502  0.945973         3.958728
# 3691  5.986750e+11  773740.933462  0.945922         3.957714
